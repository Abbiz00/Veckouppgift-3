# %% [markdown]
# 1 Diskutera i grupp
# Skriv ner vad du tror kommer skrivas ut. Skriv sedan in koden i din IDE, exakt som den står, och kör den.
#
# Den som kommer skriva ut är:
# 5
# 7
# 9
# 11
# 13
# 15
#
# Först är index 5 och skrivs ut
# därefter lägger den på 2 och loopar tills index är mindre eller lika med 15

# %%
from wsgiref.util import guess_scheme

import total

limit = 15
index = 5
while index <= limit:
    print(index)
    index = index +2
# Out:
# 5
# 7
# 9
# 11
# 13
# 15

# %% [markdown]
# 2 Vad skrivs ut?
# Först är i 0, sedan kontrolleras det om i är lika med 5 som den inte är och 0 skrivs ut.
# Där efter loopar den till i är lika med 5 och ett tomt värde skriv ut.
# Därefter skrivs 6 till 9 ut tills range är mindre än 10

# %%
for i in range (10):
    if i == 5:
        print("")
    else:
        print(i)
    i = i + 1
# Out:
# 0
# 1
# 2
# 3
# 4
#
# 6
# 7
# 8
# 9

# %% [markdown]
# 3 Vad blir summan? Skriv ner din bästa gissning innan du kör koden.
# counter är: 0, 1, 2, 3, 4, 5
# summan i loopen är 0+1+2+3+4+5 = 15

# %%
counter = 0
for i in range(6):
    counter +=i
print(counter)
# Out:
# 15

# %% [markdown]
# 3 Vad blir summan? Skriv ner din bästa gissning innan du kör koden.

# %%
x = 0
y = 1
while y < 10:
    if y % 2 == 0:
        x -= y
    else:
        x += y * y
    y +=1

# %% [markdown]
# 5 Vad skrivs ut?
# Kan du göra om koden så att den skriver ut "time" i stället?
# den skriver ut time i stället

# %%
from datetime import datetime
message = "its_time_to_get_coding"
date_now = datetime.now()
print(message[3:7])
print(message[4:8])
# En extra övning med tiden i stället för time. Två varianter
print(str(date_now)[11:19])
print(date_now.strftime("%H:%M:%S"))
# Out:
# _tim
# time
# 18:57:24
# 18:57:24

# %% [markdown]
# 6 Vad skrivs ut?
# Kan du flytta linjen ett steg åt höger?

# %%
for y in range(1, 7):
    s = ""
    for x in range(1, 9):
        if x == y:
            s += "#"
        else:
            s += "."
    print(s)
# Out:
# #.......
# .#......
# ..#.....
# ...#....
# ....#...
# .....#..

# %%
for y in range(2, 8):
    s = ""
    for x in range(1, 9):
        if x == y:
            s += "#"
        else:
            s += "."
    print(s)
# Out:
# .#......
# ..#.....
# ...#....
# ....#...
# .....#..
# ......#.

# %% [markdown]
# 2 Öva på loopar och listor
# 1a Skriv färdigt kodexemplet.
# answer = 0
# for i in ????????????:
#     answer += i
# print("Summan av talen 1 till 10 är: " + str(answer))
# # Svaret ska bli 55

# %%
answer = 0
for i in range(1, 11):
    answer += i
print("Summan av talen 1 till 10 är: " + str(answer))
# Svaret ska bli 55
# Out:
# Summan av talen 1 till 10 är: 55

# %% [markdown]
# 1b Räkna ut summan av alla tal mellan 1 och 100. (inklusive 1 och 100, rätt svar ska bli 5050)

# %%
answer = 0
for i in range(1, 101):
    answer += i
print("Summan av alla tal mellan 1 till 100 är: " + str(answer))
# Out:
# Summan av alla tal mellan 1 till 100 är: 5050

# %% [markdown]
# 1c Skriv om 1b så att den använder en while-loop.

# %%
answer = 0
i = 1

while i <= 100:
    i += 1
    answer += i

print("Summan av alla tal mellan 1 och 100 är: " + str(answer))
# Out:
# Summan av alla tal mellan 1 och 100 är: 5150

# %% [markdown]
# 2 Räkna ut summan av alla elementen i listan: [1, -2, 3, -2, 4, -3]

# %%
import numpy as np   # använder NumPy då den är snabbare

element = np.array ([1,-2,3,-2,4,-3])
print(np.sum(element))
# Out:
# 1

# %% [markdown]
# 3 Träna på att skapa och manipulera listor. Alla uppgifter ska lösas med funktionerna som står i presentationen.

# %% [markdown]
# 3a Skapa en lista med namnen på fyra filmer. Namnen ska vara strängar. Skriv ut hela listan med funktionen print.

# %%
import numpy as np
movie_array = np.array (["Inception", "Interstellar", "The Dark Knight","The Shawshank Redemption"])

def print_list(movies_array):
    for movie in movie_array:
          print(movie)

print_list(movie_array)
# Out:
# Inception
# Interstellar
# The Dark Knight
# The Shawshank Redemption

# %% [markdown]
# 3b Lägg till "Fellowship of the ring" sist i listan.

# %%
import numpy as np
movie_array = np.array (["Inception", "Interstellar", "The Dark Knight","The Shawshank Redemption"])

def print_list(movie_list):
    for movie in movie_list:
          print(movie)

def add_item_last(array_1, movie):
    movie_array_add_last = np.append(array_1, movie)
    return movie_array_add_last

# add Fellowship last
movie_array = add_item_last(movie_array, "Fellowship of the ring")

#print function
print_list(movie_array)
# Out:
# Inception
# Interstellar
# The Dark Knight
# The Shawshank Redemption
# Fellowship of the ring

# %% [markdown]
# 3c Lägg till "The two towers" på första platsen i listan. (index noll)

# %%
import numpy as np
movie_array = np.array (["Inception", "Interstellar", "The Dark Knight","The Shawshank Redemption"])

def print_list(movie_list):
    for movie in movie_list:
          print(movie)

def add_item_last(array_1, movie):
    movie_array_add_last = np.append(array_1, movie)
    return movie_array_add_last

def add_item_first(array_1, movie):
    movie_array_add_first = np.insert(array_1, 0 , movie)
    return movie_array_add_first


# add Fellowship last
movie_array = add_item_last(movie_array, "Fellowship of the ring")

# add the two towers first
movie_array = add_item_first(movie_array, "The two towers")

#print function
print_list(movie_array)
# Out:
# The two towers
# Inception
# Interstellar
# The Dark Knight
# The Shawshank Redemption
# Fellowship of the ring

# %% [markdown]
# 3d Ta reda på vilken position (index) "Fellowship of the ring" har nu.

# %%
import numpy as np
movie_array = np.array (["Inception", "Interstellar", "The Dark Knight","The Shawshank Redemption"])

def print_list(movie_list):
    for movie in movie_list:
          print(movie)

def add_item_last(array_1, movie):
    movie_array_add_last = np.append(array_1, movie)
    return movie_array_add_last

def add_item_first(array_1, movie):
    movie_array_add_first = np.insert(array_1, 0 , movie)
    return movie_array_add_first


def find_index(array_1, movie):
    movie_index = np.where(array_1 == movie)[0]
    #kika på innehållet
    #print(movie_array_in)
    if len(movie_index) > 0:
        print(f'"{movie}" finns på index: {movie_index[0]}')
    else:
        print(f'"{movie}" Filmen finns inte i listan')

# add Fellowship last
movie_array = add_item_last(movie_array, "Fellowship of the ring")

# add the two towers first
movie_array = add_item_first(movie_array, "The two towers")

#print function
#print_list(movie_array)

find_index(movie_array, "Fellowship of the ring")
# Out:
# "Fellowship of the ring" finns på index: 5

# %% [markdown]
# 3e Ta bort en annan av filmerna. Har Fellowship-filmen ändrat index?

# %% [markdown]
# 3f Ta reda på hur lång listan är. (len)

# %%
import numpy as np
movie_array = np.array (["Inception", "Interstellar", "The Dark Knight","The Shawshank Redemption"])

def print_list(movie_list):
    for movie in movie_list:
          print(movie)

def add_item_last(array_1, movie):
    movie_array_add_last = np.append(array_1, movie)
    return movie_array_add_last

def add_item_first(array_1, movie):
    movie_array_add_first = np.insert(array_1, 0 , movie)
    return movie_array_add_first


def find_index(array_1, movie):
    movie_index = np.where(array_1 == movie)[0]
    #kika på innehållet
    #print(movie_array_in)
    if len(movie_index) > 0:
        print(f'"{movie}" finns på index: {movie_index[0]}')
    else:
        print(f'"{movie}" Filmen finns inte i listan')

def remove_item(array_1, movie):
    movie_index = np.where(array_1 == movie)[0]
    if len(movie_index) > 0:
        array_1 = np.delete(array_1, movie_index[0])
    return array_1

def length_index(array_1):
    len_index =len(array_1)
    #print("array lista")
    # print(array_1)  TEST
    if len(array_1) > 0:
        print("Antal element ")
        print(len_index)

## add Fellowship last
movie_array = add_item_last(movie_array, "Fellowship of the ring")

# add the two towers first
movie_array = add_item_first(movie_array, "The two towers")

#print function
print_list(movie_array)
# skriver ut index
find_index(movie_array, "Fellowship of the ring")

# tar bort Inception
movie_array = remove_item(movie_array, "Inception")
print("")

#skriver ut lista efter borttagning
print_list(movie_array)
# skriver ut index
find_index(movie_array, "Fellowship of the ring")
print("")

#skriver ut antal rader index
length_index(movie_array)
# Out:
# The two towers
# Inception
# Interstellar
# The Dark Knight
# The Shawshank Redemption
# Fellowship of the ring
# "Fellowship of the ring" finns på index: 5
#
# The two towers
# Interstellar
# The Dark Knight
# The Shawshank Redemption
# Fellowship of the ring
# "Fellowship of the ring" finns på index: 4
#
# Antal element
# 5

# %% [markdown]
# 3g Vänd listan baklänges.

# %%
import numpy as np
movie_array = np.array (["Inception", "Interstellar", "The Dark Knight","The Shawshank Redemption"])

# funktion skriv ut lista
def print_list(movie_list):
    for movie in movie_list:
          print(movie)

# funktion lägg till sist
def add_item_last(array_1, movie):
    movie_array_add_last = np.append(array_1, movie)
    return movie_array_add_last

# funktion lägg till först
def add_item_first(array_1, movie):
    movie_array_add_first = np.insert(array_1, 0 , movie)
    return movie_array_add_first

# funktion skriv ut plats i index
def find_index(array_1, movie):
    movie_index = np.where(array_1 == movie)[0]
    #kika på innehållet
    #print(movie_array_in)
    if len(movie_index) > 0:
        print(f'"{movie}" finns på index: {movie_index[0]}')
    else:
        print(f'"{movie}" Filmen finns inte i listan')

# funktion ta bort ett element
def remove_item(array_1, movie):
    movie_index = np.where(array_1 == movie)[0]
    if len(movie_index) > 0:
        array_1 = np.delete(array_1, movie_index[0])
    return array_1

# funktion skriva ut antal element
def length_index(array_1):
    len_index =len(array_1)
    # print("array lista")
    # print(array_1)   # kontroll utskrift av lista

    if len(array_1) > 0:
        print("Antal element ")
        print(len_index)

# funktion skriva ut baklänges
def backwords_index(array_1):
        for movie in np.flip(array_1):
            print(movie)


## add Fellowship last
movie_array = add_item_last(movie_array, "Fellowship of the ring")

# add the two towers first
movie_array = add_item_first(movie_array, "The two towers")

#print function
print_list(movie_array)
# skriver ut index
find_index(movie_array, "Fellowship of the ring")

# tar bort Inception
movie_array = remove_item(movie_array, "Inception")
print("")

#skriver ut lista efter borttagning
print_list(movie_array)
# skriver ut index
find_index(movie_array, "Fellowship of the ring")
print("")

#skriver ut antal rader index
length_index(movie_array)
print ("")

#skriver ut listan baklänges
backwords_index(movie_array)
# Out:
# The two towers
# Inception
# Interstellar
# The Dark Knight
# The Shawshank Redemption
# Fellowship of the ring
# "Fellowship of the ring" finns på index: 5
#
# The two towers
# Interstellar
# The Dark Knight
# The Shawshank Redemption
# Fellowship of the ring
# "Fellowship of the ring" finns på index: 4
#
# Antal element
# 5
#
# Fellowship of the ring
# The Shawshank Redemption
# The Dark Knight
# Interstellar
# The two towers

# %% [markdown]
# 3h Sortera listan stigande i bokstavsordning.

# %%
import numpy as np
movie_array = np.array (["Inception", "Interstellar", "The Dark Knight","The Shawshank Redemption"])

# funktion skriv ut lista
def print_list(movie_list):
    for movie in movie_list:
          print(movie)

# funktion lägg till sist
def add_item_last(array_1, movie):
    movie_array_add_last = np.append(array_1, movie)
    return movie_array_add_last

# funktion lägg till först
def add_item_first(array_1, movie):
    movie_array_add_first = np.insert(array_1, 0 , movie)
    return movie_array_add_first

# funktion skriv ut plats i index
def find_index(array_1, movie):
    movie_index = np.where(array_1 == movie)[0]
    #kika på innehållet
    #print(movie_array_in)
    if len(movie_index) > 0:
        print(f'"{movie}" finns på index: {movie_index[0]}')
    else:
        print(f'"{movie}" Filmen finns inte i listan')

# funktion ta bort ett element
def remove_item(array_1, movie):
    movie_index = np.where(array_1 == movie)[0]
    if len(movie_index) > 0:
        array_1 = np.delete(array_1, movie_index[0])
    return array_1

# funktion skriva ut antal element
def length_index(array_1):
    len_index =len(array_1)
    # print("array lista")
    # print(array_1)   # kontroll utskrift av lista

    if len(array_1) > 0:
        print("Antal element ")
        print(len_index)

# funktion skriva ut baklänges
def backwords_index(array_1):
        print("Baklänges")
        for movie in np.flip(array_1):
            print(movie)

# funktion sortera lista i bokstavsordning
def sort_index(array_1):
        print ("Bokstavsordning")
        for movie in np.sort(array_1):
            print(movie)

## add Fellowship last
movie_array = add_item_last(movie_array, "Fellowship of the ring")

# add the two towers first
movie_array = add_item_first(movie_array, "The two towers")

#print function
print_list(movie_array)
# skriver ut index
find_index(movie_array, "Fellowship of the ring")

# tar bort Inception
movie_array = remove_item(movie_array, "Inception")
print("")

#skriver ut lista efter borttagning
print_list(movie_array)
# skriver ut index
find_index(movie_array, "Fellowship of the ring")
print("")

#skriver ut antal rader index
length_index(movie_array)
print ("")

#skriver ut listan baklänges
backwords_index(movie_array)
print("")

#skriver ut sorterad lita
sort_index(movie_array)
# Out:
# The two towers
# Inception
# Interstellar
# The Dark Knight
# The Shawshank Redemption
# Fellowship of the ring
# "Fellowship of the ring" finns på index: 5
#
# The two towers
# Interstellar
# The Dark Knight
# The Shawshank Redemption
# Fellowship of the ring
# "Fellowship of the ring" finns på index: 4
#
# Antal element
# 5
#
# Baklänges
# Fellowship of the ring
# The Shawshank Redemption
# The Dark Knight
# Interstellar
# The two towers
#
# Bokstavsordning
# Fellowship of the ring
# Interstellar
# The Dark Knight
# The Shawshank Redemption
# The two towers

# %% [markdown]
# 3 Kvittouträknaren
# Gör ett program som upprepade gånger ber användaren skriva in ett tal. När man skriver in strängen "quit" eller "avsluta" ska programmet ska det räkna ut summan av talen. Exempel:
# Välkommen till Kvittokompis! Avsluta genom att skriva: quit
# Skriv in ett belopp: 25
# Skriv in ett belopp: 50
# Skriv in ett belopp: quit
# Det blir 75 kr totalt. Välkommen åter!
#
# Tips! För att lösa uppgiften behöver du: flera variabler, input, while-loop.

# %%
print("kvittouträknare räknar summan på inmatade tal")

array_tal = []
while True:
    tal = (input("Skriv in ett tal eller quit för att avsluta "))

    if tal == "quit":
        break

    try:
        array_tal.append (float(tal))

    except ValueError:
        print("Felaktigt inmatning prova igen")

sum_tot=sum(array_tal)

print(f"Det blir {round(sum_tot, 2)} kr totalt. Välkommen åter!")
# Out:
# kvittouträknare räknar summan på inmatade tal
# Det blir 24.0 kr totalt. Välkommen åter!

# %% [markdown]
# Version 2: programmet ska fråga hur många man är, och tala om hur mycket varje person i sällskapet ska betala.
# Hur många är ni? 3
# Det blir 75 kr totalt, alltså 25.0 kr per person. Välkommen åter!

# %%
print("kvittouträknare räknar summan på inmatade tal")

array_tal = []
while True:
    tal = (input("Skriv in ett tal eller quit för att avsluta "))

    if tal == "quit":
        break

    try:
        array_tal.append (float(tal))

    except ValueError:
        print("Felaktigt inmatning prova igen")

sum_tot=sum(array_tal)

while True:
    how_many_guests = (input("Skriv hur många ni är i sällskapet, så delas beloppet lika"))

    try:
        how_many_guests = int(how_many_guests)
        break

    except ValueError:
        print("Skriv in ett tal")

print(f"Det blir {round(sum_tot/how_many_guests, 2)} kr per person. Välkommen åter!")
# Out:
# kvittouträknare räknar summan på inmatade tal
# Det blir 150.0 kr per person. Välkommen åter!

# %% [markdown]
# Version 3: programmet ska fråga hur många procent dricks man vill lägga på. Om användaren inte skriver något (tom sträng) ska programmet använda 10% som standardinställning.
#
# Nice to have: prova att använda try+except eller isdigit för att hantera de fall när användaren skriver ett felaktigt värde. Python Try Except , isdigit | StackOverflow
# ("Nice to have" handlar om funktionalitet som inte är nödvändig, men som är bra att ha. Gå gärna vidare till nästa uppgift och återvänd till den här om du vill lära dig mer.)

# %%
print("kvittouträknare räknar summan på inmatade tal")

array_tal = []
while True:
    tal = (input("Skriv in ett tal eller quit för att avsluta "))

    if tal == "quit":
        break

    try:
        array_tal.append (float(tal))

    except ValueError:
        print("Felaktigt inmatning prova igen")

sum_tot=sum(array_tal)

while True:
    how_many_guests = (input("Skriv hur många ni är i sällskapet, så delas beloppet lika"))

    try:
        how_many_guests = int(how_many_guests)
        break

    except ValueError:
        print("Skriv in ett tal")

while True:
    tip = (input("Skriv hur hur mycket dricks ni vill ge? (Tryck enter för 10%"))

    try:
        if not tip:
           tip =10

        tip = int(tip)
        print(f"Ni har gett {tip}% i dricks")
        print(f"summa att betala med dricks {round(sum_tot* (1+ tip/100),2)}")
        total_with_tip_per_person = (sum_tot * (1 + tip / 100))/how_many_guests
        print(f"Nya summan per person med dicks blir {round(total_with_tip_per_person,2)} kr per person")
        break


    except ValueError:
        print("Skriv in ett tal")
# Out:
# kvittouträknare räknar summan på inmatade tal
# Ni har gett 25% i dricks
# summa att betala med dricks 125.0
# Nya summan per person med dicks blir 62.5 kr per person

# %% [markdown]
# a

# %%
for y in range(1, 7):
    s = ""
    for x in range(1, 9):
        if x == 1:
            s += "#"
        else:
            s += "."
    print(s)
# Out:
# #.......
# #.......
# #.......
# #.......
# #.......
# #.......

# %% [markdown]
# b

# %%
for y in range(1, 7):
    s = ""
    for x in range(1, 9):
        if x == y:
            s += "#"
        else:
            s += "."
    print(s)
# Out:
# #.......
# .#......
# ..#.....
# ...#....
# ....#...
# .....#..

# %% [markdown]
# c

# %%
for y in range(1, 7):
    s = ""
    for x in range(1, 9):
        if x == 3:
            s += "#"
        elif x == 4:
            s += "#"
        elif x == 5:
            s += "#"
        else:
            s += "."
    print(s)
# Out:
# ..###...
# ..###...
# ..###...
# ..###...
# ..###...
# ..###...

# %% [markdown]
# d

# %%
for y in range(1, 7):
    s = ""
    for x in range(1, 9):
        if x == 3:
            s += "#"
        elif y== 3:
            s += "#"
        else:
            s += "."
    print(s)
# Out:
# ..#.....
# ..#.....
# ########
# ..#.....
# ..#.....
# ..#.....

# %% [markdown]
# e

# %%
for y in range(1, 7):
    s = ""
    for x in range(1, 9):
        if x == 5 and y == 1:
            s += "#"
        elif x == 6 and y == 1:
            s += "#"
        elif x == 5 and y == 2:
            s += "#"
        elif x== 4 and y == 3:
            s += "#"
        elif x== 5 and y == 3:
            s += "#"
        elif x== 3 and y == 4:
            s += "#"
        elif x== 5 and y == 4:
            s += "#"
        elif x== 2 and y == 5:
            s += "#"
        elif x== 5 and y == 5:
            s += "#"
        elif x== 1 and y == 6:
            s += "#"
        elif x== 5 and y == 6:
            s += "#"
        else:
            s += "."
    print(s)
# Out:
# ....##..
# ....#...
# ...##...
# ..#.#...
# .#..#...
# #...#...

# %% [markdown]
# f

# %%
for y in range(1, 7):
    s = ""
    for x in range(1, 9):
        s += "#" if (x == y or x == 7 - y) else "."
    print(s)
# Out:
# #....#..
# .#..#...
# ..##....
# ..##....
# .#..#...
# #....#..

# %% [markdown]
# g

# %%
for y in range(1, 7):
    s = ""
    for x in range(1, 9):
        if x % 2 != 0:
            s += "#"
        else:
            s += "."
    print(s)
# Out:
# #.#.#.#.
# #.#.#.#.
# #.#.#.#.
# #.#.#.#.
# #.#.#.#.
# #.#.#.#.

# %% [markdown]
# h

# %%
for y in range(1, 7):
    s = ""
    for x in range(1, 9):
        if x == 2 and y == 2:
            s += "#"
        elif x == 3 and y == 2:
            s += "#"
        elif x == 4 and y == 2:
            s += "#"
        elif x== 5 and y == 2:
            s += "#"
        elif x== 6 and y == 2:
            s += "#"
        elif x== 7 and y == 2:
            s += "#"
        elif x== 2 and y == 3:
            s += "#"
        elif x== 7 and y == 3:
            s += "#"
        elif x== 2 and y == 4:
            s += "#"
        elif x== 7 and y == 4:
            s += "#"
        elif x== 2 and y == 5:
            s += "#"
        elif x== 3 and y == 5:
            s += "#"
        elif x== 4 and y == 5:
            s += "#"
        elif x== 5 and y == 5:
            s += "#"
        elif x== 6 and y == 5:
            s += "#"
        elif x== 7 and y == 5:
            s += "#"
        else:
            s += "."
    print(s)
# Out:
# ........
# .######.
# .#....#.
# .#....#.
# .######.
# ........

# %% [markdown]
# i, kom tyvärr inte på något kortare, men det borde gå för mönstret repeterar sig

# %%
for y in range(1, 7):
    s = ""
    for x in range(1, 9):
        if x == 2 and y == 1:
            s += "#"
        elif x == 3 and y == 1:
            s += "O"
        elif x == 5 and y == 1:
            s += "#"
        elif x== 6 and y == 1:
            s += "O"
        elif x== 8 and y == 1:
            s += "#"
        elif x== 1 and y == 2:
            s += "O"
        elif x== 3 and y == 2:
            s += "#"
        elif x== 4 and y == 2:
            s += "O"
        elif x== 6 and y == 2:
            s += "#"
        elif x== 7 and y == 2:
            s += "O"
        elif x== 1 and y == 3:
            s += "#"
        elif x== 2 and y == 3:
            s += "O"
        elif x== 4 and y == 3:
            s += "#"
        elif x== 5 and y == 3:
            s += "O"
        elif x== 7 and y == 3:
            s += "#"
        elif x== 8 and y == 3:
            s += "O"
        elif x== 2 and y == 4:
            s += "#"
        elif x== 3 and y == 4:
            s += "O"
        elif x== 5 and y == 4:
            s += "#"
        elif x== 6 and y == 4:
            s += "O"
        elif x== 8 and y == 4:
            s += "#"
        elif x== 1 and y == 5:
            s += "O"
        elif x== 3 and y == 5:
            s += "#"
        elif x== 4 and y == 5:
            s += "O"
        elif x== 6 and y == 5:
            s += "#"
        elif x== 7 and y == 5:
            s += "O"
        elif x== 1 and y == 6:
            s += "#"
        elif x== 2 and y == 6:
            s += "O"
        elif x== 4 and y == 6:
            s += "#"
        elif x== 5 and y == 6:
            s += "O"
        elif x== 7 and y == 6:
            s += "#"
        elif x== 8 and y == 6:
            s += "O"
        else:
            s += "."

    print(s)
# Out:
# .#O.#O.#
# O.#O.#O.
# #O.#O.#O
# .#O.#O.#
# O.#O.#O.
# #O.#O.#O

# %% [markdown]
# j, löser uppgiften, men man kan säkert göra det på ett bättre sätt

# %%
for y in range(1, 7):
    s = ""
    for x in range(1, 9):
        if x == 3 and y == 1:
            s += "#"
        elif x == 6 and y == 1:
            s += "#"
        elif x == 3 and y == 2:
            s += "#"
        elif x== 6 and y == 2:
            s += "#"
        elif x== 3 and y == 3:
            s += "#"
        elif x== 6 and y == 3:
            s += "#"
        elif x== 2 and y == 5:
            s += "#"
        elif x== 4 and y == 5:
            s += "#"
        elif x== 6 and y == 5:
            s += "#"
        elif x== 8 and y == 5:
            s += "#"
        elif x== 1 and y == 6:
            s += "#"
        elif x== 3 and y == 6:
            s += "#"
        elif x==5 and y == 6:
            s += "#"
        elif x== 7 and y == 6:
            s += "#"
        else:
            s += "."

    print(s)
# Out:
# ..#..#..
# ..#..#..
# ..#..#..
# ........
# .#.#.#.#
# #.#.#.#.

# %% [markdown]
# 5 Gissa talet
# Gör ett spel som slumpar ett hemligt tal mellan 1 och 100. Sedan ska man försöka gissa det. Om man gissar för lågt eller för högt ska spelet tala om det. Efter att man har gissat rätt ska spelet skriva ut antalet gissningar.
#
# # Slumpa ett hemligt tal
# secret = random.randint(1, 100)
#
# Exempel:
# Välkommen till gissa talet! Jag tänker på ett tal mellan 1 och 100. Kan du gissa vilket det är?
# Gissa: 40
# Nej, det är för lågt!
# Gissa: 55
# Nej, det är för högt!
# Gissa: 51
# Det är rätt!! Du gjorde det på 3 gissningar.
#
# Version 2: skriv ut om man är nära ifall man gissar högst 5 ifrån det rätta svaret.
# "Nu börjar det brännas!"

# %%
import random

print("Välkommen till gissa talet! Jag tänker på ett tal mellan 1 och 100. Kan du gissa vilket det är?")

random_nr = random.randint(1, 100)
guess_number = ""
print(random_nr)

while guess_number != random_nr:

    guess_number = input("Skriv in din gissning")
    try:
        guess_number = int(guess_number)
    except ValueError:
        print("Du måsta ange ett tal")

    if guess_number < 1 or guess_number > 100:
        print(f"Du har gissat på {guess_number} numret måste vara mellan 1 och 100 ")

    elif (random_nr - 6) < guess_number < random_nr:
        print("Det börjar brännas!")

    elif random_nr < guess_number < (random_nr + 6):
        print("Det börjar brännas!")

    elif guess_number < random_nr:
        print("Din gissning är för låg")

    elif guess_number > random_nr:
        print("Din gissning är för hög")

    else:
        print("din gissning är rätt")
# Out:
# Välkommen till gissa talet! Jag tänker på ett tal mellan 1 och 100. Kan du gissa vilket det är?
# 54
# din gissning är rätt

# %% [markdown]
# 6 Todo list (att göra-lista)
# Bygg ett program där användaren kan lägga till saker till en todo-lista.
# Tips: använd en loop, input och en variabel för listan.
# Exempel:
#
# ** Todo list extravaganza **
# 1. Se innehållet i din lista
# 2. Lägga till nya punkter i din lista
# Välj ett alternativ: 1
# Din lista är tom
# .
# Välj ett alternativ: 2
# Skriv in en ny sak du måste komma ihåg att göra: mata guldfisken
# Ok, lade till "mata guldfisken" i listan.
# .
# Välj ett alternativ: 1
# + Mata guldfisken
# .

# %% [markdown]
# ** Todo list extravaganza **
# 1. Se innehållet i din lista

# %%
import numpy as np
array_1 = np.array ([])

# funktion skriv ut lista
def print_list(array):
    for task in array:
          print(task)

def add_item(input_array, task):
    array_add = np.append(input_array, task)
    return array_add

task_input=input("Skriv in en arbetsuppgift")
array_1 = add_item(array_1, task_input)
print_list(array_1)
# Out:
# jobba

# %% [markdown]
# 2. Lägga till nya punkter i din lista

# %%
import numpy as np
array_1 = np.array ([])

# funktion skriv ut lista
def print_list(array):
    if len(array) == 0:
        print("listan är tom")
        return
    for task in array:
        print(task)

def add_item(input_array, task):
    array_add = np.append(input_array, task)
    print(f"Ok, lade till {task} i listan")
    return array_add

while True:
    print("\n1. Lista arbetsuppgifter")
    print("2. Lägg till arbetsuppgifter")
    print("3. Avsluta")
    print("\n")
    menu=input("välj ett alternativ")

    if menu  == "3":
        break

    elif  menu == "1":
        print_list(array_1)

    elif menu == "2":
        task_input = input("Skriv in en arbetsuppgift: ")
        array_1 = add_item(array_1, task_input)

    else:
        print("Försök igen")
# Out:
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Avsluta
#
#
# listan är tom
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Avsluta
#
#
# Ok, lade till jobba i listan
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Avsluta
#
#
# Ok, lade till diska i listan
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Avsluta
#
#
# jobba
# diska
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Avsluta
#
#
# Ok, lade till springa i listan
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Avsluta
#
#
# jobba
# diska
# springa
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Avsluta
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[332], line 22
#      18     print("\n1. Lista arbetsuppgifter")
#      19     print("2. Lägg till arbetsuppgifter")
# ...

# %% [markdown]
# Version 2: lägg till ett menyalternativ, "Markera som klar". När användaren väljer det, ska programmet fråga efter vilken grej man är färdig med. Den färdiga grejen ska tas bort från listan.

# %%
import numpy as np
array_1 = np.array ([])

# funktion skriv ut lista
def print_list(array):
    if len(array) == 0:
        print("listan är tom")
        return
    for i, task in enumerate(array, start=1):
        print(f"{i}. {task}")

def add_item(input_array, task):
    array_add = np.append(input_array, task)
    print(f"Ok, lade till {task} i listan")
    return array_add

def ready(array):
    if len(array) == 0:
        print("listan är tom")
        return array

    print_list(array)
    delete_items =input("Vilken uppgift är du klar med? Ange nummer:")

    try:
        index =int(delete_items) -1
        if 0 <= index < len(array):
            print(f"{array[index]} är klar")
            array = np.delete(array, index)
            return array
        else:
            print("fel")
    except ValueError:
        print("Ange ett tal")
    return array


while True:
    print("\n1. Lista arbetsuppgifter")
    print("2. Lägg till arbetsuppgifter")
    print("3. Markera som klar")
    print("4. Avsluta")
    print("\n")
    menu=input("välj ett alternativ")


    if menu  == "4":
        break

    elif  menu == "1":
        print_list(array_1)

    elif menu == "2":
        task_input = input("Skriv in en arbetsuppgift: ")
        array_1 = add_item(array_1, task_input)

    elif menu == "3":
        array_1 = ready(array_1)

    else:
        print("Försök igen")
# Out:
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Markera som klar
# 4. Avsluta
#
#
# Ok, lade till jobba i listan
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Markera som klar
# 4. Avsluta
#
#
# Försök igen
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Markera som klar
# 4. Avsluta
#
#
# Försök igen
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Markera som klar
# 4. Avsluta
#
#
# 1. jobba
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Markera som klar
# 4. Avsluta
#
#
# Ok, lade till diska i listan
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Markera som klar
# 4. Avsluta
#
#
# Ok, lade till sova i listan
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Markera som klar
# 4. Avsluta
#
#
# 1. jobba
# 2. diska
# 3. sova
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Markera som klar
# 4. Avsluta
#
#
# 1. jobba
# 2. diska
# 3. sova
# ...

# %% [markdown]
# Version 3: lägg över färdiga grejer i en ny lista. Användaren ska kunna välja vad man har bockat av tidigare, eller välja att lägga tillbaka grejen i todo-listan.

# %%
import numpy as np
array_1 = np.array ([])
array_2 = np.array ([])

# funktion skriv ut lista
def print_list(array):
    if len(array) == 0:
        print("listan är tom")
        return
    for i, task in enumerate(array, start=1):
        print(f"{i}. {task}")

def add_item(input_array, task):
    array_add = np.append(input_array, task)
    print(f"Ok, lade till {task} i listan")
    return array_add

def delete(array):
    if len(array) == 0:
        print("listan är tom")
        return array

    print_list(array)
    delete_items =input("Vilken uppgift är du klar med? Ange nummer:")

    try:
        index =int(delete_items) -1
        if 0 <= index < len(array):
            print(f"{array[index]} är klar")
            array = np.delete(array, index)
            return array
        else:
            print("fel")
    except ValueError:
        print("error")
    return array


def move_ready(array_1, array_2):
    if len(array_1) == 0:
        print("listan är tom")
        return array_1, array_2

    print_list(array_1)
    move_items =input("Vilken uppgift vill du flytta? Ange nummer:")

    try:
        index = int(move_items) -1
        if 0 <= index < len(array_1):
            task = array_1[index]
            array_2 = np.append(array_2, task)
            array_1 = np.delete(array_1, index)
            print(f"{task} flyttad till klar")

        else:
            print(" Ogiltigt nummer")
    except ValueError:
        print(" Ange ett tal")
    return array_1, array_2

def move_not_ready(array_1, array_2):
    if len(array_2) == 0:
        print("Klarlistan är tom")
        return array_1, array_2

    print("\nKlara uppgifter:")
    print_list(array_2)
    move_items = input("Vilken uppgift vill du flytta tillbaka? Ange nummer: ")

    try:
        index = int(move_items) - 1
        if 0 <= index < len(array_2):
            task = array_2[index]
            array_1 = np.append(array_1, task)
            array_2 = np.delete(array_2, index)
            print(f"  '{task}' flyttad tillbaka till arbetslistan!")
        else:
            print("Ogiltigt nummer")
    except ValueError:
        print(" Ange ett tal")
    return array_1, array_2




while True:
    print("\n1. Lista arbetsuppgifter")
    print("2. Lägg till arbetsuppgifter")
    print("3. Ta bort")
    print("4  Flytta till klarlista")
    print("5  Flytta tillbaka från klarlista")
    print("6. Avsluta")
    print("\n")
    menu=input("välj ett alternativ")


    if menu  == "6":
        break

    elif  menu == "1":
        print_list(array_1)

    elif menu == "2":
        task_input = input("Skriv in en arbetsuppgift: ")
        array_1 = add_item(array_1, task_input)

    elif menu == "3":
        array_1 = delete(array_1)

    elif menu == "4":
        print("meny 4")
        array_1, array_2 = move_ready(array_1, array_2)

    elif menu == "5":
        print("meny5")
        array_1, array_2 = move_not_ready(array_1, array_2)

    else:
        print("Försök igen")
# Out:
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Markera som klar
# 4  Flytta till klarlista
# 5  Flytta tillbaka från klarlista
# 6. Avsluta
#
#
# Ok, lade till kissa i listan
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Markera som klar
# 4  Flytta till klarlista
# 5  Flytta tillbaka från klarlista
# 6. Avsluta
#
#
# Ok, lade till jobba i listan
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Markera som klar
# 4  Flytta till klarlista
# 5  Flytta tillbaka från klarlista
# 6. Avsluta
#
#
# 1. kissa
# 2. jobba
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Markera som klar
# 4  Flytta till klarlista
# 5  Flytta tillbaka från klarlista
# 6. Avsluta
#
#
# meny 4
# 1. kissa
# 2. jobba
# jobba flyttad till klar
#
# 1. Lista arbetsuppgifter
# 2. Lägg till arbetsuppgifter
# 3. Markera som klar
# 4  Flytta till klarlista
# 5  Flytta tillbaka från klarlista
# 6. Avsluta
#
#
# 1. kissa
#
# 1. Lista arbetsuppgifter
# ...
