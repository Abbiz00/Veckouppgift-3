# %% [markdown]
# 1 Diskutera i grupp
# Skriv ner vad du tror kommer skrivas ut. Skriv sedan in koden i din IDE, exakt som den står, och kör den.
#
# Den som kommer skriva ut är:
# 5
# 7
# 9
# 11
# 13
# 15
#
# Först är index 5 och skrivs ut
# därefter lägger den på 2 och loopar tills index är mindre eller lika med 15

# %%
import total

limit = 15
index = 5
while index <= limit:
    print(index)
    index = index +2
# Out:
# 5
# 7
# 9
# 11
# 13
# 15

# %% [markdown]
# 2 Vad skrivs ut?
# Först är i 0, sedan kontrolleras det om i är lika med 5 som den inte är och 0 skrivs ut.
# Där efter loopar den till i är lika med 5 och ett tomt värde skriv ut.
# Därefter skrivs 6 till 9 ut tills range är mindre än 10

# %%
for i in range (10):
    if i == 5:
        print("")
    else:
        print(i)
    i = i + 1
# Out:
# 0
# 1
# 2
# 3
# 4
#
# 6
# 7
# 8
# 9

# %% [markdown]
# 3 Vad blir summan? Skriv ner din bästa gissning innan du kör koden.
# counter är: 0, 1, 2, 3, 4, 5
# summan i loopen är 0+1+2+3+4+5 = 15

# %%
counter = 0
for i in range(6):
    counter +=i
print(counter)
# Out:
# 15

# %% [markdown]
# 3 Vad blir summan? Skriv ner din bästa gissning innan du kör koden.

# %%
x = 0
y = 1
while y < 10:
    if y % 2 == 0:
        x -= y
    else:
        x += y * y
    y +=1

# %% [markdown]
# 5 Vad skrivs ut?
# Kan du göra om koden så att den skriver ut "time" i stället?
# den skriver ut time i stället

# %%
from datetime import datetime
message = "its_time_to_get_coding"
date_now = datetime.now()
print(message[3:7])
print(message[4:8])
# En extra övning med tiden i stället för time. Två varianter
print(str(date_now)[11:19])
print(date_now.strftime("%H:%M:%S"))
# Out:
# _tim
# time
# 12:33:14
# 12:33:14

# %% [markdown]
# 6 Vad skrivs ut?
# Kan du flytta linjen ett steg åt höger?

# %%
for y in range(1, 7):
    s = ""
    for x in range(1, 9):
        if x == y:
            s += "#"
        else:
            s += "."
    print(s)
# Out:
# #.......
# .#......
# ..#.....
# ...#....
# ....#...
# .....#..

# %%
for y in range(2, 8):
    s = ""
    for x in range(1, 9):
        if x == y:
            s += "#"
        else:
            s += "."
    print(s)
# Out:
# .#......
# ..#.....
# ...#....
# ....#...
# .....#..
# ......#.

# %% [markdown]
# 2 Öva på loopar och listor
# 1a Skriv färdigt kodexemplet.
# answer = 0
# for i in ????????????:
#     answer += i
# print("Summan av talen 1 till 10 är: " + str(answer))
# # Svaret ska bli 55

# %%
answer = 0
for i in range(1, 11):
    answer += i
print("Summan av talen 1 till 10 är: " + str(answer))
# Svaret ska bli 55
# Out:
# Summan av talen 1 till 10 är: 55

# %% [markdown]
# 1b Räkna ut summan av alla tal mellan 1 och 100. (inklusive 1 och 100, rätt svar ska bli 5050)

# %%
answer = 0
for i in range(1, 101):
    answer += i
print("Summan av alla tal mellan 1 till 100 är: " + str(answer))
# Out:
# Summan av alla tal mellan 1 till 100 är: 5050

# %% [markdown]
# 1c Skriv om 1b så att den använder en while-loop.

# %%
answer = 0
while answer < 100:
    total += answer
    answer += 1
print("Summan av alla tal mellan 1 till 100 är: " + str(total))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 3
#       1 answer = 0
#       2 while answer < 100:
# ----> 3     total += answer
#       4     answer += 1
#       5 print("Summan av alla tal mellan 1 till 100 är: " + str(total))
#
# NameError: name 'total' is not defined
